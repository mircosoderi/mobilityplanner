# %% [markdown]
# <h1>Mobility Planner</h1>
#
# This notebook was produced in the context of the Applied Data Science Capstone Project "The Battle of Neighborhoods", that is a part of the [IBM Data Science Professional Certificate offered on Coursera](https://www.coursera.org/specializations/ibm-data-science).
#
# Below here, I will try building a tool that could be used by public decision makers for planning the strengthening of mobility-related services and infrastructures.
#
# The tool highlights those areas where mobility services appear not to be adequate given the attractiveness of the area.
#
# See https://github.com/mircosoderi/mobilityplanner to learn more.

# %% [markdown]
# <h3>How to use this notebook</h3>
#
# The notebook is partitioned into a sequence of steps.
#
# At each step, you will find one of these:
#
# <p><span style="font-size:larger;">&#128583;</span> means <i>Take action!</i>, it is where you have to make your hands dirty</p>
# <p><span style="font-size:larger;">&#128582;</span> means <i>Enjoy!</i>, it is where you just have to run cells and relax</p>

# %% [markdown]
# <h3> &#128583; Step 1 - Configuration</h3>
#
# In the code cell below here, indicate the city for which you wish to perform the analysis, and other parameters.

# %%
# For which city do you wish to perform the analysis?
city = "Montelupo Fiorentino"

# How about the minimum size of each squared partition of the territory subject to analysis?
min_side_length = 500

# How about the impact of private and public transport facilities and infrastructures over the quantification of quality of mobility?
pvt_tpt_wgt = 1
pbl_tpt_wgt = 2

# How about the impact of Open Street Map nodes and FourSquare likes over the quantification of attractiveness?
osm_nodes_wgt = 1
fs_likes_wgt = 2

# %% [markdown]
# <h3> &#128582; Step 2 - Bounding box of the city</h3>
#
# Just execute the cell below here to query the Open Street Map for the city that you have specified above, and get back its bounding box.

# %%
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import pandas as pd
geolocator = Nominatim(user_agent="ny_explorer")
bbox = pd.DataFrame(geolocator.geocode(city,exactly_one=True).raw)['boundingbox']
lat_min = float(bbox[0])
lon_min = float(bbox[2])
lat_max = float(bbox[1])
lon_max = float(bbox[3])
print(lat_min,lon_min,lat_max,lon_max)
# Out:
# 43.6933031 10.9760734 43.7675612 11.06845

# %% [markdown]
# <h3> &#128582; Step 3 - Bounding box partitioning</h3>
#
# The bounding box is partitioned in squares whose side is the 1% of the minimum between the height and the width of the bounding box obtained at Step 2, or _min_side_length_ if less.
#
# Run cells here below to initialize the table of partitions.

# %%
class Partition:
    lat_min = 0
    lon_min = 0
    lat_max = 0
    lon_max = 0
    osm_df = 0
    osm_nodes = 0    
    osm_pbl_tpt = 0
    osm_highways = 0
    osm_parkings = 0
    osm_rentals = 0
    fs_df = 0
    fs_likes = 0
    attractiveness_val = 0
    attractiveness_cat = 0
    mobility_val = 0
    mobility_cat = 0
    gap = 0
print("Class definition: OK")
# Out:
# Class definition: OK

# %%
from math import pi, cos, ceil
# See https://amsi.org.au/ESA_Senior_Years/SeniorTopic8/8b/8b_2content_5.html for:
bbox_h_m = abs ( 6400 * pi / 180 * ( lat_max - lat_min ) ) * 1000
# See http://spmmathematics.blog.onlinetuition.com.my/2016/05/942-distance-between-two-points-along.html for:
bbox_w_m = ( lon_max - lon_min ) * 60 * cos( ( lat_max + lat_min ) / 2 ) * 1.852 * 1000
# side length = 1% of min(bboxHeight,bboxWidth) or 100 m if less
side_l_m = max(min_side_length,min(bbox_h_m,bbox_w_m)/100)
# inverse formulas to calculate delta lat/lon, given the side length
delta_lat = side_l_m / 1000 / 6400 / pi * 180
delta_lon = side_l_m / 60 / cos( ( lat_max + lat_min ) / 2 ) / 1.852 / 1000
# shaping table of territory partitions
partitions_w = ceil( ( lon_max - lon_min ) / delta_lon )
partitions_h = ceil( ( lat_max - lat_min ) / delta_lat )
partitions_tbl = [[0 for x in range(partitions_w)] for y in range(partitions_h)] 
for y in range(partitions_h):
    for x in range(partitions_w):
        partitions_tbl[y][x] = Partition();
        partitions_tbl[y][x].lat_max = lat_max - y*delta_lat
        partitions_tbl[y][x].lon_min = lon_min + x*delta_lon
        partitions_tbl[y][x].lat_min = partitions_tbl[y][x].lat_max - delta_lat
        partitions_tbl[y][x].lon_max = partitions_tbl[y][x].lon_min + delta_lon
print("Partitions initialization: OK")
# Out:
# Partitions initialization: OK

# %% [markdown]
# <h3> &#128582; Step 4 - Open Street Map querying</h3>
#
# Run the cells here below to start filling partitions with data that can be gathered from the Open Street Map

# %%
for y in range(partitions_h):
    for x in range(partitions_w):
        partitions_tbl[y][x].osm_df = pd.read_csv("https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node("+str(partitions_tbl[y][x].lat_min)+","+str(partitions_tbl[y][x].lon_min)+","+str(partitions_tbl[y][x].lat_max)+","+str(partitions_tbl[y][x].lon_max)+");%20%3C;%20);%20out%20meta;",sep='\t')
        print("https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node("+str(partitions_tbl[y][x].lat_min)+","+str(partitions_tbl[y][x].lon_min)+","+str(partitions_tbl[y][x].lat_max)+","+str(partitions_tbl[y][x].lon_max)+");%20%3C;%20);%20out%20meta;")
# Out:
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,10.9760734,43.7675612,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,10.980719631760879,43.7675612,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,10.985365863521757,43.7675612,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,10.990012095282633,43.7675612,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,10.994658327043512,43.7675612,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,10.99930455880439,43.7675612,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.003950790565268,43.7675612,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.008597022326144,43.7675612,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.013243254087023,43.7675612,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.0178894858479,43.7675612,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.022535717608779,43.7675612,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.027181949369657,43.7675612,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.031828181130534,43.7675612,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.036474412891412,43.7675612,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.04112064465229,43.7675612,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.045766876413168,43.7675612,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.050413108174046,43.7675612,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.055059339934923,43.7675612,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.059705571695801,43.7675612,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.763084967225545,11.06435180345668,43.7675612,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,10.9760734,43.763084967225545,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,10.980719631760879,43.763084967225545,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,10.985365863521757,43.763084967225545,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,10.990012095282633,43.763084967225545,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,10.994658327043512,43.763084967225545,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,10.99930455880439,43.763084967225545,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.003950790565268,43.763084967225545,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.008597022326144,43.763084967225545,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.013243254087023,43.763084967225545,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.0178894858479,43.763084967225545,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.022535717608779,43.763084967225545,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.027181949369657,43.763084967225545,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.031828181130534,43.763084967225545,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.036474412891412,43.763084967225545,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.04112064465229,43.763084967225545,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.045766876413168,43.763084967225545,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.050413108174046,43.763084967225545,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.055059339934923,43.763084967225545,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.059705571695801,43.763084967225545,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75860873445109,11.06435180345668,43.763084967225545,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,10.9760734,43.75860873445109,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,10.980719631760879,43.75860873445109,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,10.985365863521757,43.75860873445109,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,10.990012095282633,43.75860873445109,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,10.994658327043512,43.75860873445109,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,10.99930455880439,43.75860873445109,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.003950790565268,43.75860873445109,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.008597022326144,43.75860873445109,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.013243254087023,43.75860873445109,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.0178894858479,43.75860873445109,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.022535717608779,43.75860873445109,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.027181949369657,43.75860873445109,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.031828181130534,43.75860873445109,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.036474412891412,43.75860873445109,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.04112064465229,43.75860873445109,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.045766876413168,43.75860873445109,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.050413108174046,43.75860873445109,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.055059339934923,43.75860873445109,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.059705571695801,43.75860873445109,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.75413250167663,11.06435180345668,43.75860873445109,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,10.9760734,43.75413250167662,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,10.980719631760879,43.75413250167662,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,10.985365863521757,43.75413250167662,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,10.990012095282633,43.75413250167662,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,10.994658327043512,43.75413250167662,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,10.99930455880439,43.75413250167662,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.003950790565268,43.75413250167662,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.008597022326144,43.75413250167662,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.013243254087023,43.75413250167662,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.0178894858479,43.75413250167662,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.022535717608779,43.75413250167662,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.027181949369657,43.75413250167662,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.031828181130534,43.75413250167662,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.036474412891412,43.75413250167662,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.04112064465229,43.75413250167662,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.045766876413168,43.75413250167662,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.050413108174046,43.75413250167662,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.055059339934923,43.75413250167662,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.059705571695801,43.75413250167662,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.749656268902164,11.06435180345668,43.75413250167662,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,10.9760734,43.749656268902164,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,10.980719631760879,43.749656268902164,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,10.985365863521757,43.749656268902164,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,10.990012095282633,43.749656268902164,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,10.994658327043512,43.749656268902164,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,10.99930455880439,43.749656268902164,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.003950790565268,43.749656268902164,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.008597022326144,43.749656268902164,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.013243254087023,43.749656268902164,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.0178894858479,43.749656268902164,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.022535717608779,43.749656268902164,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.027181949369657,43.749656268902164,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.031828181130534,43.749656268902164,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.036474412891412,43.749656268902164,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.04112064465229,43.749656268902164,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.045766876413168,43.749656268902164,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.050413108174046,43.749656268902164,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.055059339934923,43.749656268902164,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.059705571695801,43.749656268902164,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74518003612771,11.06435180345668,43.749656268902164,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,10.9760734,43.74518003612771,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,10.980719631760879,43.74518003612771,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,10.985365863521757,43.74518003612771,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,10.990012095282633,43.74518003612771,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,10.994658327043512,43.74518003612771,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,10.99930455880439,43.74518003612771,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.003950790565268,43.74518003612771,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.008597022326144,43.74518003612771,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.013243254087023,43.74518003612771,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.0178894858479,43.74518003612771,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.022535717608779,43.74518003612771,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.027181949369657,43.74518003612771,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.031828181130534,43.74518003612771,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.036474412891412,43.74518003612771,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.04112064465229,43.74518003612771,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.045766876413168,43.74518003612771,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.050413108174046,43.74518003612771,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.055059339934923,43.74518003612771,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.059705571695801,43.74518003612771,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.74070380335325,11.06435180345668,43.74518003612771,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,10.9760734,43.74070380335325,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,10.980719631760879,43.74070380335325,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,10.985365863521757,43.74070380335325,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,10.990012095282633,43.74070380335325,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,10.994658327043512,43.74070380335325,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,10.99930455880439,43.74070380335325,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.003950790565268,43.74070380335325,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.008597022326144,43.74070380335325,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.013243254087023,43.74070380335325,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.0178894858479,43.74070380335325,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.022535717608779,43.74070380335325,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.027181949369657,43.74070380335325,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.031828181130534,43.74070380335325,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.036474412891412,43.74070380335325,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.04112064465229,43.74070380335325,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.045766876413168,43.74070380335325,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.050413108174046,43.74070380335325,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.055059339934923,43.74070380335325,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.059705571695801,43.74070380335325,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.73622757057879,11.06435180345668,43.74070380335325,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,10.9760734,43.736227570578784,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,10.980719631760879,43.736227570578784,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,10.985365863521757,43.736227570578784,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,10.990012095282633,43.736227570578784,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,10.994658327043512,43.736227570578784,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,10.99930455880439,43.736227570578784,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.003950790565268,43.736227570578784,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.008597022326144,43.736227570578784,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.013243254087023,43.736227570578784,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.0178894858479,43.736227570578784,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.022535717608779,43.736227570578784,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.027181949369657,43.736227570578784,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.031828181130534,43.736227570578784,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.036474412891412,43.736227570578784,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.04112064465229,43.736227570578784,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.045766876413168,43.736227570578784,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.050413108174046,43.736227570578784,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.055059339934923,43.736227570578784,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.059705571695801,43.736227570578784,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.731751337804326,11.06435180345668,43.736227570578784,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,10.9760734,43.731751337804326,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,10.980719631760879,43.731751337804326,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,10.985365863521757,43.731751337804326,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,10.990012095282633,43.731751337804326,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,10.994658327043512,43.731751337804326,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,10.99930455880439,43.731751337804326,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.003950790565268,43.731751337804326,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.008597022326144,43.731751337804326,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.013243254087023,43.731751337804326,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.0178894858479,43.731751337804326,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.022535717608779,43.731751337804326,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.027181949369657,43.731751337804326,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.031828181130534,43.731751337804326,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.036474412891412,43.731751337804326,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.04112064465229,43.731751337804326,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.045766876413168,43.731751337804326,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.050413108174046,43.731751337804326,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.055059339934923,43.731751337804326,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.059705571695801,43.731751337804326,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72727510502987,11.06435180345668,43.731751337804326,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,10.9760734,43.72727510502987,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,10.980719631760879,43.72727510502987,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,10.985365863521757,43.72727510502987,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,10.990012095282633,43.72727510502987,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,10.994658327043512,43.72727510502987,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,10.99930455880439,43.72727510502987,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.003950790565268,43.72727510502987,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.008597022326144,43.72727510502987,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.013243254087023,43.72727510502987,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.0178894858479,43.72727510502987,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.022535717608779,43.72727510502987,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.027181949369657,43.72727510502987,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.031828181130534,43.72727510502987,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.036474412891412,43.72727510502987,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.04112064465229,43.72727510502987,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.045766876413168,43.72727510502987,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.050413108174046,43.72727510502987,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.055059339934923,43.72727510502987,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.059705571695801,43.72727510502987,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.72279887225541,11.06435180345668,43.72727510502987,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,10.9760734,43.72279887225541,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,10.980719631760879,43.72279887225541,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,10.985365863521757,43.72279887225541,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,10.990012095282633,43.72279887225541,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,10.994658327043512,43.72279887225541,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,10.99930455880439,43.72279887225541,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,11.003950790565268,43.72279887225541,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,11.008597022326144,43.72279887225541,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,11.013243254087023,43.72279887225541,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,11.0178894858479,43.72279887225541,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,11.022535717608779,43.72279887225541,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.71832263948095,11.027181949369657,43.72279887225541,11.031828181130535);%20%3C;%20);%20out%20meta;
# ...
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.022535717608779,43.70937017393203,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.027181949369657,43.70937017393203,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.031828181130534,43.70937017393203,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.036474412891412,43.70937017393203,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.04112064465229,43.70937017393203,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.045766876413168,43.70937017393203,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.050413108174046,43.70937017393203,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.055059339934923,43.70937017393203,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.059705571695801,43.70937017393203,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.70489394115757,11.06435180345668,43.70937017393203,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,10.9760734,43.70489394115757,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,10.980719631760879,43.70489394115757,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,10.985365863521757,43.70489394115757,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,10.990012095282633,43.70489394115757,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,10.994658327043512,43.70489394115757,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,10.99930455880439,43.70489394115757,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.003950790565268,43.70489394115757,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.008597022326144,43.70489394115757,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.013243254087023,43.70489394115757,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.0178894858479,43.70489394115757,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.022535717608779,43.70489394115757,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.027181949369657,43.70489394115757,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.031828181130534,43.70489394115757,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.036474412891412,43.70489394115757,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.04112064465229,43.70489394115757,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.045766876413168,43.70489394115757,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.050413108174046,43.70489394115757,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.055059339934923,43.70489394115757,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.059705571695801,43.70489394115757,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.700417708383114,11.06435180345668,43.70489394115757,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,10.9760734,43.70041770838311,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,10.980719631760879,43.70041770838311,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,10.985365863521757,43.70041770838311,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,10.990012095282633,43.70041770838311,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,10.994658327043512,43.70041770838311,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,10.99930455880439,43.70041770838311,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.003950790565268,43.70041770838311,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.008597022326144,43.70041770838311,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.013243254087023,43.70041770838311,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.0178894858479,43.70041770838311,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.022535717608779,43.70041770838311,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.027181949369657,43.70041770838311,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.031828181130534,43.70041770838311,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.036474412891412,43.70041770838311,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.04112064465229,43.70041770838311,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.045766876413168,43.70041770838311,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.050413108174046,43.70041770838311,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.055059339934923,43.70041770838311,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.059705571695801,43.70041770838311,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69594147560865,11.06435180345668,43.70041770838311,11.068998035217557);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,10.9760734,43.69594147560865,10.980719631760879);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,10.980719631760879,43.69594147560865,10.985365863521757);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,10.985365863521757,43.69594147560865,10.990012095282635);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,10.990012095282633,43.69594147560865,10.994658327043512);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,10.994658327043512,43.69594147560865,10.99930455880439);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,10.99930455880439,43.69594147560865,11.003950790565268);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.003950790565268,43.69594147560865,11.008597022326146);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.008597022326144,43.69594147560865,11.013243254087023);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.013243254087023,43.69594147560865,11.0178894858479);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.0178894858479,43.69594147560865,11.022535717608779);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.022535717608779,43.69594147560865,11.027181949369657);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.027181949369657,43.69594147560865,11.031828181130535);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.031828181130534,43.69594147560865,11.036474412891412);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.036474412891412,43.69594147560865,11.04112064465229);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.04112064465229,43.69594147560865,11.045766876413168);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.045766876413168,43.69594147560865,11.050413108174046);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.050413108174046,43.69594147560865,11.055059339934925);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.055059339934923,43.69594147560865,11.059705571695801);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.059705571695801,43.69594147560865,11.06435180345668);%20%3C;%20);%20out%20meta;
# https://overpass.kumi.systems/api/interpreter?data=[out:csv(::id,::type,public_transport,highway,cycleway,amenity)];(%20node(43.69146524283419,11.06435180345668,43.69594147560865,11.068998035217557);%20%3C;%20);%20out%20meta;

# %% [markdown]
# <h3> &#128582; Step 5 - Open Street Map exploitation</h3>
#
# Run the cell here below to quantify the quality of mobility for each partition, and start quantifying attractiveness, based on data gathered from the Open Street Map at the previous step.

# %%
for y in range(partitions_h):
    for x in range(partitions_w):
        partitions_tbl[y][x].osm_nodes = len(partitions_tbl[y][x].osm_df[partitions_tbl[y][x].osm_df["@type"] == "node"])
        partitions_tbl[y][x].osm_pbl_tpt = partitions_tbl[y][x].osm_df["public_transport"].count()
        partitions_tbl[y][x].osm_highways = partitions_tbl[y][x].osm_df["highway"].count()
        partitions_tbl[y][x].osm_parkings = len(partitions_tbl[y][x].osm_df[partitions_tbl[y][x].osm_df["amenity"] == "parking"])
        partitions_tbl[y][x].osm_rentals = len(partitions_tbl[y][x].osm_df[partitions_tbl[y][x].osm_df["amenity"] == "bicycle_rental"])
        partitions_tbl[y][x].mobility_val = pvt_tpt_wgt * (partitions_tbl[y][x].osm_highways+partitions_tbl[y][x].osm_parkings+partitions_tbl[y][x].osm_rentals) + \
                                        pbl_tpt_wgt * partitions_tbl[y][x].osm_pbl_tpt        
        partitions_tbl[y][x].attractiveness_val = osm_nodes_wgt*partitions_tbl[y][x].osm_nodes
print("Open Street Map exploitation: OK")
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Open Street Map exploitation: OK

# %% [markdown]
# <h3> &#128582; Step 6 - Clustering by mobility</h3>
#
# Run the cell here below to cluster partitions of territory on the basis of the quantification of the quality of mobility in each of them.

# %%
from sklearn.cluster import KMeans 
k_means_mobility = KMeans(init = "k-means++", n_clusters = 3, n_init = 12)
pts_mobility = []
for y in range(partitions_h):
    for x in range(partitions_w):
        pts_mobility.append([partitions_tbl[y][x].mobility_val])
k_means_mobility.fit(pts_mobility)
result_mobility_clustering = k_means_mobility.labels_
centers_mobility_clustering = k_means_mobility.cluster_centers_
i = 0
for y in range(partitions_h):
    for x in range(partitions_w):
        partitions_tbl[y][x].mobility_cat = result_mobility_clustering[i]
        print("Partition ("+str(y)+", "+str(x)+") is in cluster "+str(partitions_tbl[y][x].mobility_cat))
        i += 1
# Out:
# Partition (0, 0) is in cluster 1
# Partition (0, 1) is in cluster 1
# Partition (0, 2) is in cluster 1
# Partition (0, 3) is in cluster 1
# Partition (0, 4) is in cluster 1
# Partition (0, 5) is in cluster 1
# Partition (0, 6) is in cluster 1
# Partition (0, 7) is in cluster 1
# Partition (0, 8) is in cluster 1
# Partition (0, 9) is in cluster 1
# Partition (0, 10) is in cluster 1
# Partition (0, 11) is in cluster 1
# Partition (0, 12) is in cluster 1
# Partition (0, 13) is in cluster 1
# Partition (0, 14) is in cluster 1
# Partition (0, 15) is in cluster 1
# Partition (0, 16) is in cluster 1
# Partition (0, 17) is in cluster 0
# Partition (0, 18) is in cluster 1
# Partition (0, 19) is in cluster 1
# Partition (1, 0) is in cluster 1
# Partition (1, 1) is in cluster 1
# Partition (1, 2) is in cluster 1
# Partition (1, 3) is in cluster 1
# Partition (1, 4) is in cluster 1
# Partition (1, 5) is in cluster 1
# Partition (1, 6) is in cluster 1
# Partition (1, 7) is in cluster 1
# Partition (1, 8) is in cluster 1
# Partition (1, 9) is in cluster 1
# Partition (1, 10) is in cluster 1
# Partition (1, 11) is in cluster 1
# Partition (1, 12) is in cluster 1
# Partition (1, 13) is in cluster 1
# Partition (1, 14) is in cluster 1
# Partition (1, 15) is in cluster 1
# Partition (1, 16) is in cluster 1
# Partition (1, 17) is in cluster 1
# Partition (1, 18) is in cluster 1
# Partition (1, 19) is in cluster 1
# Partition (2, 0) is in cluster 1
# Partition (2, 1) is in cluster 1
# Partition (2, 2) is in cluster 1
# Partition (2, 3) is in cluster 1
# Partition (2, 4) is in cluster 1
# Partition (2, 5) is in cluster 1
# Partition (2, 6) is in cluster 1
# Partition (2, 7) is in cluster 1
# Partition (2, 8) is in cluster 1
# Partition (2, 9) is in cluster 1
# Partition (2, 10) is in cluster 1
# Partition (2, 11) is in cluster 0
# Partition (2, 12) is in cluster 1
# Partition (2, 13) is in cluster 1
# Partition (2, 14) is in cluster 1
# Partition (2, 15) is in cluster 1
# Partition (2, 16) is in cluster 1
# Partition (2, 17) is in cluster 1
# Partition (2, 18) is in cluster 1
# Partition (2, 19) is in cluster 1
# Partition (3, 0) is in cluster 1
# Partition (3, 1) is in cluster 1
# Partition (3, 2) is in cluster 1
# Partition (3, 3) is in cluster 1
# Partition (3, 4) is in cluster 1
# Partition (3, 5) is in cluster 1
# Partition (3, 6) is in cluster 1
# Partition (3, 7) is in cluster 1
# Partition (3, 8) is in cluster 1
# Partition (3, 9) is in cluster 1
# Partition (3, 10) is in cluster 1
# Partition (3, 11) is in cluster 1
# Partition (3, 12) is in cluster 1
# Partition (3, 13) is in cluster 1
# Partition (3, 14) is in cluster 1
# Partition (3, 15) is in cluster 1
# Partition (3, 16) is in cluster 1
# Partition (3, 17) is in cluster 1
# Partition (3, 18) is in cluster 1
# Partition (3, 19) is in cluster 1
# Partition (4, 0) is in cluster 0
# Partition (4, 1) is in cluster 0
# Partition (4, 2) is in cluster 1
# Partition (4, 3) is in cluster 0
# Partition (4, 4) is in cluster 1
# Partition (4, 5) is in cluster 1
# Partition (4, 6) is in cluster 1
# Partition (4, 7) is in cluster 1
# Partition (4, 8) is in cluster 1
# Partition (4, 9) is in cluster 1
# Partition (4, 10) is in cluster 1
# Partition (4, 11) is in cluster 1
# Partition (4, 12) is in cluster 1
# Partition (4, 13) is in cluster 1
# Partition (4, 14) is in cluster 1
# Partition (4, 15) is in cluster 1
# Partition (4, 16) is in cluster 1
# Partition (4, 17) is in cluster 1
# Partition (4, 18) is in cluster 1
# Partition (4, 19) is in cluster 1
# Partition (5, 0) is in cluster 0
# Partition (5, 1) is in cluster 0
# Partition (5, 2) is in cluster 0
# Partition (5, 3) is in cluster 0
# Partition (5, 4) is in cluster 1
# Partition (5, 5) is in cluster 1
# Partition (5, 6) is in cluster 1
# Partition (5, 7) is in cluster 1
# Partition (5, 8) is in cluster 1
# Partition (5, 9) is in cluster 1
# Partition (5, 10) is in cluster 1
# Partition (5, 11) is in cluster 0
# Partition (5, 12) is in cluster 1
# Partition (5, 13) is in cluster 1
# Partition (5, 14) is in cluster 1
# Partition (5, 15) is in cluster 1
# Partition (5, 16) is in cluster 1
# Partition (5, 17) is in cluster 1
# Partition (5, 18) is in cluster 0
# Partition (5, 19) is in cluster 0
# Partition (6, 0) is in cluster 1
# Partition (6, 1) is in cluster 1
# Partition (6, 2) is in cluster 1
# Partition (6, 3) is in cluster 1
# Partition (6, 4) is in cluster 1
# Partition (6, 5) is in cluster 1
# Partition (6, 6) is in cluster 0
# Partition (6, 7) is in cluster 0
# Partition (6, 8) is in cluster 0
# Partition (6, 9) is in cluster 1
# Partition (6, 10) is in cluster 0
# Partition (6, 11) is in cluster 0
# Partition (6, 12) is in cluster 1
# Partition (6, 13) is in cluster 1
# Partition (6, 14) is in cluster 1
# Partition (6, 15) is in cluster 1
# Partition (6, 16) is in cluster 1
# Partition (6, 17) is in cluster 1
# Partition (6, 18) is in cluster 1
# Partition (6, 19) is in cluster 1
# Partition (7, 0) is in cluster 1
# Partition (7, 1) is in cluster 1
# Partition (7, 2) is in cluster 1
# Partition (7, 3) is in cluster 1
# Partition (7, 4) is in cluster 1
# Partition (7, 5) is in cluster 1
# Partition (7, 6) is in cluster 1
# Partition (7, 7) is in cluster 1
# Partition (7, 8) is in cluster 0
# Partition (7, 9) is in cluster 2
# Partition (7, 10) is in cluster 0
# Partition (7, 11) is in cluster 1
# Partition (7, 12) is in cluster 1
# Partition (7, 13) is in cluster 1
# Partition (7, 14) is in cluster 1
# Partition (7, 15) is in cluster 1
# Partition (7, 16) is in cluster 1
# Partition (7, 17) is in cluster 1
# Partition (7, 18) is in cluster 1
# Partition (7, 19) is in cluster 1
# Partition (8, 0) is in cluster 1
# Partition (8, 1) is in cluster 1
# Partition (8, 2) is in cluster 1
# Partition (8, 3) is in cluster 1
# Partition (8, 4) is in cluster 0
# Partition (8, 5) is in cluster 0
# Partition (8, 6) is in cluster 0
# Partition (8, 7) is in cluster 0
# Partition (8, 8) is in cluster 0
# Partition (8, 9) is in cluster 2
# Partition (8, 10) is in cluster 0
# Partition (8, 11) is in cluster 1
# Partition (8, 12) is in cluster 1
# Partition (8, 13) is in cluster 1
# Partition (8, 14) is in cluster 1
# Partition (8, 15) is in cluster 1
# Partition (8, 16) is in cluster 1
# Partition (8, 17) is in cluster 1
# Partition (8, 18) is in cluster 1
# Partition (8, 19) is in cluster 1
# Partition (9, 0) is in cluster 1
# Partition (9, 1) is in cluster 1
# Partition (9, 2) is in cluster 1
# Partition (9, 3) is in cluster 1
# Partition (9, 4) is in cluster 1
# Partition (9, 5) is in cluster 1
# Partition (9, 6) is in cluster 1
# Partition (9, 7) is in cluster 0
# Partition (9, 8) is in cluster 0
# Partition (9, 9) is in cluster 0
# Partition (9, 10) is in cluster 0
# Partition (9, 11) is in cluster 1
# Partition (9, 12) is in cluster 1
# Partition (9, 13) is in cluster 1
# Partition (9, 14) is in cluster 1
# Partition (9, 15) is in cluster 1
# Partition (9, 16) is in cluster 1
# Partition (9, 17) is in cluster 1
# Partition (9, 18) is in cluster 1
# Partition (9, 19) is in cluster 1
# Partition (10, 0) is in cluster 0
# Partition (10, 1) is in cluster 0
# Partition (10, 2) is in cluster 1
# Partition (10, 3) is in cluster 1
# Partition (10, 4) is in cluster 1
# Partition (10, 5) is in cluster 1
# Partition (10, 6) is in cluster 1
# Partition (10, 7) is in cluster 1
# Partition (10, 8) is in cluster 1
# Partition (10, 9) is in cluster 1
# Partition (10, 10) is in cluster 1
# Partition (10, 11) is in cluster 1
# Partition (10, 12) is in cluster 0
# Partition (10, 13) is in cluster 1
# Partition (10, 14) is in cluster 1
# Partition (10, 15) is in cluster 1
# Partition (10, 16) is in cluster 1
# Partition (10, 17) is in cluster 1
# Partition (10, 18) is in cluster 1
# Partition (10, 19) is in cluster 1
# Partition (11, 0) is in cluster 1
# Partition (11, 1) is in cluster 1
# Partition (11, 2) is in cluster 1
# Partition (11, 3) is in cluster 1
# Partition (11, 4) is in cluster 1
# Partition (11, 5) is in cluster 1
# Partition (11, 6) is in cluster 1
# Partition (11, 7) is in cluster 1
# Partition (11, 8) is in cluster 1
# Partition (11, 9) is in cluster 1
# Partition (11, 10) is in cluster 1
# Partition (11, 11) is in cluster 1
# Partition (11, 12) is in cluster 1
# Partition (11, 13) is in cluster 1
# Partition (11, 14) is in cluster 1
# Partition (11, 15) is in cluster 1
# Partition (11, 16) is in cluster 1
# Partition (11, 17) is in cluster 1
# Partition (11, 18) is in cluster 1
# Partition (11, 19) is in cluster 1
# Partition (12, 0) is in cluster 1
# Partition (12, 1) is in cluster 1
# Partition (12, 2) is in cluster 1
# Partition (12, 3) is in cluster 1
# Partition (12, 4) is in cluster 1
# Partition (12, 5) is in cluster 1
# Partition (12, 6) is in cluster 1
# Partition (12, 7) is in cluster 1
# Partition (12, 8) is in cluster 1
# Partition (12, 9) is in cluster 1
# Partition (12, 10) is in cluster 1
# Partition (12, 11) is in cluster 1
# Partition (12, 12) is in cluster 1
# Partition (12, 13) is in cluster 1
# Partition (12, 14) is in cluster 1
# Partition (12, 15) is in cluster 1
# Partition (12, 16) is in cluster 1
# Partition (12, 17) is in cluster 0
# Partition (12, 18) is in cluster 0
# Partition (12, 19) is in cluster 0
# Partition (13, 0) is in cluster 1
# Partition (13, 1) is in cluster 1
# Partition (13, 2) is in cluster 1
# Partition (13, 3) is in cluster 1
# Partition (13, 4) is in cluster 1
# Partition (13, 5) is in cluster 1
# Partition (13, 6) is in cluster 1
# Partition (13, 7) is in cluster 1
# Partition (13, 8) is in cluster 1
# Partition (13, 9) is in cluster 1
# Partition (13, 10) is in cluster 1
# Partition (13, 11) is in cluster 1
# Partition (13, 12) is in cluster 1
# Partition (13, 13) is in cluster 1
# Partition (13, 14) is in cluster 1
# Partition (13, 15) is in cluster 1
# Partition (13, 16) is in cluster 1
# Partition (13, 17) is in cluster 1
# Partition (13, 18) is in cluster 1
# Partition (13, 19) is in cluster 1
# Partition (14, 0) is in cluster 1
# Partition (14, 1) is in cluster 1
# Partition (14, 2) is in cluster 1
# Partition (14, 3) is in cluster 1
# Partition (14, 4) is in cluster 1
# Partition (14, 5) is in cluster 1
# Partition (14, 6) is in cluster 1
# Partition (14, 7) is in cluster 1
# Partition (14, 8) is in cluster 1
# Partition (14, 9) is in cluster 1
# Partition (14, 10) is in cluster 1
# Partition (14, 11) is in cluster 1
# Partition (14, 12) is in cluster 1
# Partition (14, 13) is in cluster 1
# Partition (14, 14) is in cluster 1
# Partition (14, 15) is in cluster 1
# Partition (14, 16) is in cluster 1
# Partition (14, 17) is in cluster 1
# Partition (14, 18) is in cluster 1
# Partition (14, 19) is in cluster 1
# Partition (15, 0) is in cluster 1
# Partition (15, 1) is in cluster 1
# Partition (15, 2) is in cluster 1
# Partition (15, 3) is in cluster 1
# Partition (15, 4) is in cluster 1
# Partition (15, 5) is in cluster 1
# Partition (15, 6) is in cluster 1
# Partition (15, 7) is in cluster 1
# Partition (15, 8) is in cluster 1
# Partition (15, 9) is in cluster 1
# Partition (15, 10) is in cluster 1
# Partition (15, 11) is in cluster 1
# Partition (15, 12) is in cluster 1
# Partition (15, 13) is in cluster 1
# Partition (15, 14) is in cluster 1
# Partition (15, 15) is in cluster 1
# Partition (15, 16) is in cluster 1
# Partition (15, 17) is in cluster 1
# Partition (15, 18) is in cluster 1
# Partition (15, 19) is in cluster 1
# Partition (16, 0) is in cluster 1
# Partition (16, 1) is in cluster 1
# Partition (16, 2) is in cluster 1
# Partition (16, 3) is in cluster 1
# Partition (16, 4) is in cluster 1
# Partition (16, 5) is in cluster 1
# Partition (16, 6) is in cluster 1
# Partition (16, 7) is in cluster 1
# Partition (16, 8) is in cluster 1
# Partition (16, 9) is in cluster 1
# Partition (16, 10) is in cluster 1
# Partition (16, 11) is in cluster 1
# Partition (16, 12) is in cluster 1
# Partition (16, 13) is in cluster 1
# Partition (16, 14) is in cluster 1
# Partition (16, 15) is in cluster 0
# Partition (16, 16) is in cluster 1
# Partition (16, 17) is in cluster 1
# Partition (16, 18) is in cluster 1
# Partition (16, 19) is in cluster 1

# %% [markdown]
# <h3> &#128583; Step 7 - Map cluster labels to mobility categories</h3>
#
# You are not granted that lowest values are grouped in cluster 0, medium in cluster 1, and highest in cluster 2.
#
# Check for _centers_mobility_clustering_ and manually map cluster labels to mobility levels if necessary.

# %%
centers_mobility_clustering
# Out:
# array([[ 32.77777778],
#        [  4.78145695],
#        [138.        ]])

# %%
# In my case, centers_mobility_clustering was
# array([[ 32.77777778],
#        [  4.78145695],
#        [138.        ]])
# So, my mapping is:
for y in range(partitions_h):
    for x in range(partitions_w):
        if partitions_tbl[y][x].mobility_cat == 0:
            mobility = 1
        if partitions_tbl[y][x].mobility_cat == 1:
            mobility = 0
        if partitions_tbl[y][x].mobility_cat == 2:
            mobility = 2
        partitions_tbl[y][x].mobility_cat = mobility

# %% [markdown]
# <h3> &#128582; Step 8 - Map of Mobility</h3>
#
# Run the cell here below to display the map of the quality of mobility in the territory of your interest.
#
# __Remark__: the map displays _relative_ quantifications of mobility, i.e. you find marked in red those areas that are less served than others _within the boundaries of the considered territory_.

# %%
# Install folium if it is not already installed in your runtime environment. I use it for composing maps.
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.6.20-hecda079_0     conda-forge
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0        conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import folium 
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors

map_mobility = folium.Map(location=[(lat_min+lat_max)/2, (lon_min+lon_max)/2], zoom_start=13)
rainbow = [colors.rgb2hex(colors.BASE_COLORS["r"]), colors.rgb2hex(colors.BASE_COLORS["y"]), colors.rgb2hex(colors.BASE_COLORS["g"])]
markers_colors = []
for y in range(partitions_h):
    for x in range(partitions_w):
        label = folium.Popup("Mobility here is "+str(partitions_tbl[y][x].mobility_cat)+" in a 0 - 2 scale", parse_html=True)
        lat = (partitions_tbl[y][x].lat_min+partitions_tbl[y][x].lat_max)/2
        lon = (partitions_tbl[y][x].lon_min+partitions_tbl[y][x].lon_max)/2        
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[partitions_tbl[y][x].mobility_cat],
            fill=True,
            fill_color=rainbow[partitions_tbl[y][x].mobility_cat],
            fill_opacity=0.7).add_to(map_mobility)       
map_mobility
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3> &#128582; Step 9 - FourSquare querying and exploitation</h3>
#
# Run the cells here below to query FourSquare for the most relevant venues in the territory of your interest, and for likes got by such venues, that contribute to the quantification of the attractiveness of each partition.

# %%
import requests
fs_client_id = 'LH053BNQIPGKBI0WU0EP5UZ124HLZXVX4Z55O1HOYNB5WB2L'
fs_client_secret = 'AW0NG4SS111TVCBGHXFXUTIBFF1OG3HEHJRCUJSST32NA2DH'
fs_version = '20180604'
fs_limit = 50
fs_venues = requests.get('https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&limit={}'.format(fs_client_id, fs_client_secret, (lat_min+lat_max)/2, (lon_min+lon_max)/2, fs_version, fs_limit)).json()
fs_venues
# Out:
# {'meta': {'code': 200, 'requestId': '5f061d53a6e8ba1788a9efbc'},
#  'response': {'venues': [{'id': '4e36e49cb61cddd1cd4ca3b5',
#     'name': 'Bar Centofiori',
#     'location': {'lat': 43.729619653955375,
#      'lng': 11.020794727396865,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.729619653955375,
#        'lng': 11.020794727396865}],
#      'distance': 148,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['50056 Montelupo Fiorentino Toscana', 'Italia']},
#     'categories': [],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '50086ce6e4b018497f90a8ca',
#     'name': 'Fontanello Montelupo',
#     'location': {'lat': 43.73023601333479,
#      'lng': 11.019602005782795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73023601333479,
#        'lng': 11.019602005782795}],
#      'distance': 215,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4ee9f67a2c5bbde217dca92f',
#     'name': 'Hotel Granducato',
#     'location': {'address': "Piazza Dell' Unione Europea, 33",
#      'crossStreet': 'Via Virgilio Rovai',
#      'lat': 43.73131591715217,
#      'lng': 11.021170216879284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73131591715217,
#        'lng': 11.021170216879284}],
#      'distance': 131,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ["Piazza Dell' Unione Europea, 33 (Via Virgilio Rovai)",
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4ed0a3ee0e01f1a880193b22',
#     'name': 'Municipio di Montelupo Fiorentino',
#     'location': {'address': 'Piazza Grande',
#      'crossStreet': 'Via Europa',
#      'lat': 43.72889383255165,
#      'lng': 11.019333772919833,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72889383255165,
#        'lng': 11.019333772919833}],
#      'distance': 291,
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza Grande (Via Europa)',
#       'Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d129941735',
#       'name': 'City Hall',
#       'pluralName': 'City Halls',
#       'shortName': 'City Hall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/cityhall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '504780b6e4b092e662da44bf',
#     'name': 'farmacia Canneri',
#     'location': {'address': 'centro storico',
#      'lat': 43.73117805065717,
#      'lng': 11.02304216416387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73117805065717,
#        'lng': 11.02304216416387}],
#      'distance': 104,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['centro storico',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5b463bbed8096e002cc0adb2',
#     'name': "I'Gelataio",
#     'location': {'address': 'Piazza Unione Europea, 6',
#      'crossStreet': 'Viale Cento Fiori',
#      'lat': 43.73053,
#      'lng': 11.020222,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73053,
#        'lng': 11.020222}],
#      'distance': 164,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza Unione Europea, 6 (Viale Cento Fiori)',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '504e556ee4b07bde9b551483',
#     'name': 'su ì prato',
#     'location': {'address': 'via bozzeto',
#      'lat': 43.72927663090535,
#      'lng': 11.02049102373625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72927663090535,
#        'lng': 11.02049102373625}],
#      'distance': 191,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Firenze',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['via bozzeto', '50056 Firenze Toscana', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4cead12dbaa6a1cdfa143b6c',
#     'name': 'Da Rossana',
#     'location': {'lat': 43.729842,
#      'lng': 11.020619,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.729842,
#        'lng': 11.020619}],
#      'distance': 147,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '57e0e31d498ec840d8791a59',
#     'name': 'cassa di risparmio firenze',
#     'location': {'lat': 43.729419,
#      'lng': 11.021459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.729419,
#        'lng': 11.021459}],
#      'distance': 129,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['50056 Montelupo Fiorentino Toscana', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5009963de4b0db14bc1bd4f7',
#     'name': 'Rosso 5',
#     'location': {'lat': 43.73052129382388,
#      'lng': 11.020954862438789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73052129382388,
#        'lng': 11.020954862438789}],
#      'distance': 105,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '55c1381f498e73397e12ea7a',
#     'name': "Piazza dell'Unione Europea",
#     'location': {'lat': 43.73149778935165,
#      'lng': 11.021181260709689,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73149778935165,
#        'lng': 11.021181260709689}],
#      'distance': 147,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['50056 Montelupo Fiorentino Toscana', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4f0361755c5c51dd31ba5e91',
#     'name': 'Ristorante Pizzeria Il Pianeta',
#     'location': {'address': 'via Virginio Rovai, 18',
#      'lat': 43.73204504933617,
#      'lng': 11.02081681497307,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73204504933617,
#        'lng': 11.02081681497307}],
#      'distance': 213,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo F.no',
#      'country': 'Italia',
#      'formattedAddress': ['via Virginio Rovai, 18',
#       '50056 Montelupo F.no',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '52248df711d2ca5731a934f2',
#     'name': 'Baraonda caffè',
#     'location': {'address': 'viale ariosto, 44',
#      'lat': 43.731274456921525,
#      'lng': 11.01810008100054,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.731274456921525,
#        'lng': 11.01810008100054}],
#      'distance': 347,
#      'postalCode': '50019',
#      'cc': 'IT',
#      'city': 'Sesto Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['viale ariosto, 44',
#       '50019 Sesto Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '531ae734498ef0f31e8a62ea',
#     'name': 'via landini montelupo fiorentino',
#     'location': {'lat': 43.725691,
#      'lng': 11.024168,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.725691,
#        'lng': 11.024168}],
#      'distance': 549,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d184941735',
#       'name': 'Stadium',
#       'pluralName': 'Stadiums',
#       'shortName': 'Stadium',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5090f25ae4b07b9c2db20d41',
#     'name': 'Filippi casalinghi',
#     'location': {'address': 'viale cento fiori 4',
#      'crossStreet': 'via caverni',
#      'lat': 43.7309,
#      'lng': 11.0187,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.7309, 'lng': 11.0187}],
#      'distance': 291,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['viale cento fiori 4 (via caverni)',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d112951735',
#       'name': 'Hardware Store',
#       'pluralName': 'Hardware Stores',
#       'shortName': 'Hardware',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4e3cebb9b61cb577be70a2d6',
#     'name': 'Banca di Credito Cooperativo di Signa',
#     'location': {'lat': 43.72785218685762,
#      'lng': 11.02025910522031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72785218685762,
#        'lng': 11.02025910522031}],
#      'distance': 329,
#      'cc': 'IT',
#      'city': 'Montelupo F.no',
#      'country': 'Italia',
#      'formattedAddress': ['Montelupo F.no', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5a3ce17ddff8156fd083762c',
#     'name': 'Vanna Cart & Copy',
#     'location': {'address': 'via Rovai 31',
#      'lat': 43.73188,
#      'lng': 11.021092,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73188,
#        'lng': 11.021092}],
#      'distance': 186,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['via Rovai 31',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d121951735',
#       'name': 'Paper / Office Supplies Store',
#       'pluralName': 'Paper / Office Supplies Stores',
#       'shortName': 'Office Supplies',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4dbc57f55da3ff58ec490008',
#     'name': 'Segni Strani Tatuaggi',
#     'location': {'address': 'Corso Garibaldi, 47',
#      'lat': 43.73412054562699,
#      'lng': 11.020253583357672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73412054562699,
#        'lng': 11.020253583357672}],
#      'distance': 441,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Corso Garibaldi, 47',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1de931735',
#       'name': 'Tattoo Parlor',
#       'pluralName': 'Tattoo Parlors',
#       'shortName': 'Tattoo',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tattoos_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5dcff15e93445c0008707a4b',
#     'name': 'Facto Molino Bistro',
#     'location': {'lat': 43.732426,
#      'lng': 11.022701,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.732426,
#        'lng': 11.022701}],
#      'distance': 224,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['50056 Montelupo Fiorentino Toscana', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4f590aa5e4b0db97b79617fd',
#     'name': "La Volpe e l'Uva",
#     'location': {'lat': 43.73256511733213,
#      'lng': 11.021661668554406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73256511733213,
#        'lng': 11.021661668554406}],
#      'distance': 242,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '53492270498eb9a16c6ae652',
#     'name': 'Bar Carlino',
#     'location': {'address': 'Viale Centofiori 9/11',
#      'lat': 43.729921479356605,
#      'lng': 11.020562808151666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.729921479356605,
#        'lng': 11.020562808151666}],
#      'distance': 148,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Viale Centofiori 9/11',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4d12547bf898b1f7af02d881',
#     'name': 'Osteria del sole',
#     'location': {'address': 'Via XX Settembre, 23',
#      'lat': 43.73314,
#      'lng': 11.0218,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.73314, 'lng': 11.0218}],
#      'distance': 303,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Via XX Settembre, 23',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5120a173e4b09380836d9d61',
#     'name': 'Tenuta Cantagallo vineyard',
#     'location': {'lat': 43.72760948554454,
#      'lng': 11.023086340349113,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72760948554454,
#        'lng': 11.023086340349113}],
#      'distance': 321,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1de941735',
#       'name': 'Vineyard',
#       'pluralName': 'Vineyards',
#       'shortName': 'Vineyard',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/vineyard_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '522a257011d2a1aabc76c44d',
#     'name': 'pizzeria maurizio e simona',
#     'location': {'lat': 43.73042297363281,
#      'lng': 11.022699356079102,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73042297363281,
#        'lng': 11.022699356079102}],
#      'distance': 35,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4f6d95c9e4b0541c618781a1',
#     'name': 'Cioccolato',
#     'location': {'lat': 43.72476227535231,
#      'lng': 11.020513111243003,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72476227535231,
#        'lng': 11.020513111243003}],
#      'distance': 646,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4cdaf9c2b1d8a090e5a055e0',
#     'name': 'Montelupo Fiorentino centro storico',
#     'location': {'address': 'Via Roma',
#      'lat': 43.73339033234532,
#      'lng': 11.020546242512602,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73339033234532,
#        'lng': 11.020546242512602}],
#      'distance': 357,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Via Roma',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5363795b498e4036c4b1c545',
#     'name': 'kebab Montelupo Fiorentino',
#     'location': {'lat': 43.73135,
#      'lng': 11.019669,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73135,
#        'lng': 11.019669}],
#      'distance': 232,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '5283c7b4e4b094cb91ec88d7',
#       'name': 'Kebab Restaurant',
#       'pluralName': 'Kebab Restaurants',
#       'shortName': 'Kebab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4d416090aae1b1f760708ff5',
#     'name': 'Linea Fontani',
#     'location': {'lat': 43.7332941,
#      'lng': 11.0215156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7332941,
#        'lng': 11.0215156}],
#      'distance': 324,
#      'cc': 'IT',
#      'city': 'Limite',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Limite Toscana', 'Italia']},
#     'categories': [],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5c24bf71a4ba7c002c0557cf',
#     'name': "Enoteca L'alternativo",
#     'location': {'address': 'via Rovai',
#      'lat': 43.730717,
#      'lng': 11.018566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.730717,
#        'lng': 11.018566}],
#      'distance': 298,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['via Rovai',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d119951735',
#       'name': 'Wine Shop',
#       'pluralName': 'Wine Shops',
#       'shortName': 'Wine Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4d1c93c309546dcb5b52d338',
#     'name': 'Osteria Livornese',
#     'location': {'lat': 43.732485924079,
#      'lng': 11.020376226953532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.732485924079,
#        'lng': 11.020376226953532}],
#      'distance': 274,
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Montelupo Fiorentino Toscana', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4f561d1e7b0ca24d35666e83',
#     'name': 'Cinema Mignon',
#     'location': {'address': 'Via Baccio da Montelupo, 31',
#      'lat': 43.73362091184081,
#      'lng': 11.021877024570736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73362091184081,
#        'lng': 11.021877024570736}],
#      'distance': 356,
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Via Baccio da Montelupo, 31',
#       'Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d17f941735',
#       'name': 'Movie Theater',
#       'pluralName': 'Movie Theaters',
#       'shortName': 'Movie Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '517c38cce4b08338cef74329',
#     'name': 'Osteria di Fuori',
#     'location': {'lat': 43.73118279393506,
#      'lng': 11.01890073652507,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73118279393506,
#        'lng': 11.01890073652507}],
#      'distance': 282,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '51a3d332498e30597fdf712b',
#     'name': "Cappellini's",
#     'location': {'lat': 43.73179210211781,
#      'lng': 11.020579373793568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73179210211781,
#        'lng': 11.020579373793568}],
#      'distance': 203,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4f5a46fee4b083219d412574',
#     'name': "Spiga D'oro",
#     'location': {'address': "Piazza Dell'Unione Europea",
#      'crossStreet': '37',
#      'lat': 43.730942,
#      'lng': 11.020704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.730942,
#        'lng': 11.020704}],
#      'distance': 137,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ["Piazza Dell'Unione Europea (37)", 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4c776355a5676dcb34a51821',
#     'name': 'Palazzetto Montelupo',
#     'location': {'address': 'Via guglielmo marconi',
#      'lat': 43.72689322901362,
#      'lng': 11.028293749689642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72689322901362,
#        'lng': 11.028293749689642}],
#      'distance': 625,
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Via guglielmo marconi',
#       'Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4ec6b516f79041351bc9d624',
#     'name': 'La Locanda Del Moro',
#     'location': {'lat': 43.731563912058604,
#      'lng': 11.020673245818022,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.731563912058604,
#        'lng': 11.020673245818022}],
#      'distance': 179,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '522258b311d24ee10f005702',
#     'name': 'Capofrio',
#     'location': {'address': 'C.so Garibaldi, 38',
#      'lat': 43.733190728417284,
#      'lng': 11.020695333366447,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.733190728417284,
#        'lng': 11.020695333366447}],
#      'distance': 331,
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['C.so Garibaldi, 38',
#       'Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '52248f03498e86279795073a',
#     'name': 'Papillametod',
#     'location': {'address': 'via Pietro Nenni, 33/2',
#      'lat': 43.73132874003585,
#      'lng': 11.017691473153507,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73132874003585,
#        'lng': 11.017691473153507}],
#      'distance': 380,
#      'postalCode': '50019',
#      'cc': 'IT',
#      'city': 'Sesto Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['via Pietro Nenni, 33/2',
#       '50019 Sesto Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4f572d35e4b0ae4d11696578',
#     'name': 'Istituto Comprensivo Baccio da Montelupo',
#     'location': {'lat': 43.72917751014356,
#      'lng': 11.016763829325319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72917751014356,
#        'lng': 11.016763829325319}],
#      'distance': 463,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4f4533804b9074f6e4fb0105',
#       'name': 'Elementary School',
#       'pluralName': 'Elementary Schools',
#       'shortName': 'Elementary School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '58149e2638fa6cfcf33607c8',
#     'name': 'cimitero sammiatello',
#     'location': {'lat': 43.73458,
#      'lng': 11.02075,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73458,
#        'lng': 11.02075}],
#      'distance': 477,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d15c941735',
#       'name': 'Cemetery',
#       'pluralName': 'Cemeteries',
#       'shortName': 'Cemetery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/cemetery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5094f773e4b055b34c700237',
#     'name': 'Mercato settimanale',
#     'location': {'address': 'viale unione europea',
#      'lat': 43.73057572695459,
#      'lng': 11.01949156934139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73057572695459,
#        'lng': 11.01949156934139}],
#      'distance': 223,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['viale unione europea',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4eb1daf44b900d56c88a4600',
#       'name': 'Fair',
#       'pluralName': 'Fairs',
#       'shortName': 'Fair',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/fair_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '50c494cde4b047e9d4d8d63a',
#     'name': 'Stadio Montelupo Fiorentino',
#     'location': {'lat': 43.726345436876194,
#      'lng': 11.024649085897934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.726345436876194,
#        'lng': 11.024649085897934}],
#      'distance': 493,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4cce455aebf7b749d5e191f5',
#       'name': 'Soccer Field',
#       'pluralName': 'Soccer Fields',
#       'shortName': 'Soccer Field',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '537e5be9498ec730b996e4da',
#     'name': 'Bar Pizzeria Seta',
#     'location': {'address': 'Corso Garibaldi 46',
#      'lat': 43.73180586962857,
#      'lng': 11.021186782625364,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73180586962857,
#        'lng': 11.021186782625364}],
#      'distance': 175,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Corso Garibaldi 46',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4d989efc647d8cfa3d73f33d',
#     'name': 'Malagigi',
#     'location': {'address': 'Corso garibaldi',
#      'lat': 43.73411975873201,
#      'lng': 11.021479444607907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73411975873201,
#        'lng': 11.021479444607907}],
#      'distance': 415,
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Corso garibaldi',
#       'Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '5221d44111d2f93a518de3e3',
#     'name': 'Mercato Settimanale Montelupo f.no',
#     'location': {'address': "piazza dell'unione europea",
#      'lat': 43.73185393804424,
#      'lng': 11.016901870997186,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73185393804424,
#        'lng': 11.016901870997186}],
#      'distance': 459,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ["piazza dell'unione europea",
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4bce951768f976b09e596683',
#     'name': 'Stazione Montelupo - Capraia',
#     'location': {'address': 'Piazza Cavallotti, 1',
#      'lat': 43.73327846840038,
#      'lng': 11.019104719161987,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73327846840038,
#        'lng': 11.019104719161987}],
#      'distance': 406,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza Cavallotti, 1',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'shortName': 'Train Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '50b26d1a498eee01f2e55b31',
#     'name': 'Pizzeria Spaghetteria Dal mangia, Bevi E Fuggi',
#     'location': {'lat': 43.729458,
#      'lng': 11.016803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.729458,
#        'lng': 11.016803}],
#      'distance': 452,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '53a2cede498e6bc264a43af1',
#     'name': 'piazza Vittorio Veneto',
#     'location': {'lat': 43.735079,
#      'lng': 11.022599,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.735079,
#        'lng': 11.022599}],
#      'distance': 517,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '51c5e862498ef33c59411601',
#     'name': 'Festa della ceramica',
#     'location': {'lat': 43.73389446841527,
#      'lng': 11.02276054145781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73389446841527,
#        'lng': 11.02276054145781}],
#      'distance': 387,
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Montelupo Fiorentino Toscana', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False},
#    {'id': '4de3875dd22d2a4ecddf05c9',
#     'name': 'Museo Della Ceramica',
#     'location': {'address': 'Piazza Vittorio Veneto 11',
#      'lat': 43.73408082498202,
#      'lng': 11.023235321044922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73408082498202,
#        'lng': 11.023235321044922}],
#      'distance': 413,
#      'postalCode': '50056',
#      'cc': 'IT',
#      'city': 'Montelupo Fiorentino',
#      'state': 'Toscana',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza Vittorio Veneto 11',
#       '50056 Montelupo Fiorentino Toscana',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d18f941735',
#       'name': 'Art Museum',
#       'pluralName': 'Art Museums',
#       'shortName': 'Art Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594236194',
#     'hasPerk': False}],
#   'confident': False}}

# %%
for y in range(partitions_h):
    for x in range(partitions_w):
        for venue in fs_venues["response"]["venues"]:
            if venue["location"]["lat"] >= partitions_tbl[y][x].lat_min and venue["location"]["lat"] <= partitions_tbl[y][x].lat_max and venue["location"]["lng"] >= partitions_tbl[y][x].lon_min and venue["location"]["lng"] <= partitions_tbl[y][x].lon_max:
                fs_likes = requests.get('https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(venue["id"],fs_client_id,fs_client_secret,fs_version)).json()
                partitions_tbl[y][x].attractiveness_val = partitions_tbl[y][x].attractiveness_val + fs_likes_wgt*fs_likes["response"]["likes"]["count"]
                print(venue["name"]+" in partition ("+str(y)+", "+str(x)+") was found to have "+str(fs_likes["response"]["likes"]["count"])+" likes")
# Out:
# Mercato Settimanale Montelupo f.no in partition (7, 8) was found to have 0 likes
# Ristorante Pizzeria Il Pianeta in partition (7, 9) was found to have 7 likes
# Vanna Cart & Copy in partition (7, 9) was found to have 0 likes
# Segni Strani Tatuaggi in partition (7, 9) was found to have 0 likes
# La Volpe e l'Uva in partition (7, 9) was found to have 1 likes
# Osteria del sole in partition (7, 9) was found to have 2 likes
# Montelupo Fiorentino centro storico in partition (7, 9) was found to have 10 likes
# Linea Fontani in partition (7, 9) was found to have 0 likes
# Osteria Livornese in partition (7, 9) was found to have 13 likes
# Cinema Mignon in partition (7, 9) was found to have 5 likes
# Cappellini's in partition (7, 9) was found to have 0 likes
# Capofrio in partition (7, 9) was found to have 1 likes
# cimitero sammiatello in partition (7, 9) was found to have 0 likes
# Bar Pizzeria Seta in partition (7, 9) was found to have 3 likes
# Malagigi in partition (7, 9) was found to have 5 likes
# Stazione Montelupo - Capraia in partition (7, 9) was found to have 1 likes
# Facto Molino Bistro in partition (7, 10) was found to have 0 likes
# piazza Vittorio Veneto in partition (7, 10) was found to have 0 likes
# Festa della ceramica in partition (7, 10) was found to have 0 likes
# Museo Della Ceramica in partition (7, 10) was found to have 3 likes
# Papillametod in partition (8, 8) was found to have 0 likes
# Istituto Comprensivo Baccio da Montelupo in partition (8, 8) was found to have 0 likes
# Pizzeria Spaghetteria Dal mangia, Bevi E Fuggi in partition (8, 8) was found to have 0 likes
# Bar Centofiori in partition (8, 9) was found to have 2 likes
# Fontanello Montelupo in partition (8, 9) was found to have 0 likes
# Hotel Granducato in partition (8, 9) was found to have 2 likes
# Municipio di Montelupo Fiorentino in partition (8, 9) was found to have 0 likes
# I'Gelataio in partition (8, 9) was found to have 0 likes
# su ì prato in partition (8, 9) was found to have 0 likes
# Da Rossana in partition (8, 9) was found to have 0 likes
# cassa di risparmio firenze in partition (8, 9) was found to have 0 likes
# Rosso 5 in partition (8, 9) was found to have 2 likes
# Piazza dell'Unione Europea in partition (8, 9) was found to have 1 likes
# Baraonda caffè in partition (8, 9) was found to have 0 likes
# Filippi casalinghi in partition (8, 9) was found to have 0 likes
# Banca di Credito Cooperativo di Signa in partition (8, 9) was found to have 1 likes
# Bar Carlino in partition (8, 9) was found to have 3 likes
# kebab Montelupo Fiorentino in partition (8, 9) was found to have 0 likes
# Enoteca L'alternativo in partition (8, 9) was found to have 0 likes
# Osteria di Fuori in partition (8, 9) was found to have 1 likes
# Spiga D'oro in partition (8, 9) was found to have 0 likes
# La Locanda Del Moro in partition (8, 9) was found to have 1 likes
# Mercato settimanale in partition (8, 9) was found to have 0 likes
# farmacia Canneri in partition (8, 10) was found to have 0 likes
# Tenuta Cantagallo vineyard in partition (8, 10) was found to have 0 likes
# pizzeria maurizio e simona in partition (8, 10) was found to have 0 likes
# Cioccolato in partition (9, 9) was found to have 1 likes
# via landini montelupo fiorentino in partition (9, 10) was found to have 0 likes
# Stadio Montelupo Fiorentino in partition (9, 10) was found to have 0 likes
# Palazzetto Montelupo in partition (9, 11) was found to have 0 likes

# %% [markdown]
# <h3> &#128582; Step 10 - Clustering by attractiveness</h3>
#
# Run the cell here below to cluster partitions of territory on the basis of the quantification of the attractiveness of each of them.

# %%
from sklearn.cluster import KMeans 
k_means_attractiveness = KMeans(init = "k-means++", n_clusters = 3, n_init = 12)
pts_attractiveness = []
for y in range(partitions_h):
    for x in range(partitions_w):
        pts_attractiveness.append([partitions_tbl[y][x].attractiveness_val])
k_means_attractiveness.fit(pts_attractiveness)
result_attractiveness_clustering = k_means_attractiveness.labels_
centers_attractiveness_clustering = k_means_attractiveness.cluster_centers_
i = 0
for y in range(partitions_h):
    for x in range(partitions_w):
        partitions_tbl[y][x].attractiveness_cat = result_attractiveness_clustering[i]
        print("Partition ("+str(y)+", "+str(x)+") is in cluster "+str(partitions_tbl[y][x].attractiveness_cat))
        i += 1
# Out:
# Partition (0, 0) is in cluster 0
# Partition (0, 1) is in cluster 0
# Partition (0, 2) is in cluster 0
# Partition (0, 3) is in cluster 0
# Partition (0, 4) is in cluster 0
# Partition (0, 5) is in cluster 0
# Partition (0, 6) is in cluster 0
# Partition (0, 7) is in cluster 0
# Partition (0, 8) is in cluster 0
# Partition (0, 9) is in cluster 0
# Partition (0, 10) is in cluster 0
# Partition (0, 11) is in cluster 0
# Partition (0, 12) is in cluster 0
# Partition (0, 13) is in cluster 2
# Partition (0, 14) is in cluster 0
# Partition (0, 15) is in cluster 0
# Partition (0, 16) is in cluster 0
# Partition (0, 17) is in cluster 2
# Partition (0, 18) is in cluster 0
# Partition (0, 19) is in cluster 0
# Partition (1, 0) is in cluster 0
# Partition (1, 1) is in cluster 0
# Partition (1, 2) is in cluster 0
# Partition (1, 3) is in cluster 0
# Partition (1, 4) is in cluster 0
# Partition (1, 5) is in cluster 0
# Partition (1, 6) is in cluster 0
# Partition (1, 7) is in cluster 0
# Partition (1, 8) is in cluster 0
# Partition (1, 9) is in cluster 0
# Partition (1, 10) is in cluster 0
# Partition (1, 11) is in cluster 0
# Partition (1, 12) is in cluster 0
# Partition (1, 13) is in cluster 0
# Partition (1, 14) is in cluster 0
# Partition (1, 15) is in cluster 0
# Partition (1, 16) is in cluster 0
# Partition (1, 17) is in cluster 0
# Partition (1, 18) is in cluster 0
# Partition (1, 19) is in cluster 0
# Partition (2, 0) is in cluster 0
# Partition (2, 1) is in cluster 0
# Partition (2, 2) is in cluster 0
# Partition (2, 3) is in cluster 0
# Partition (2, 4) is in cluster 0
# Partition (2, 5) is in cluster 0
# Partition (2, 6) is in cluster 0
# Partition (2, 7) is in cluster 0
# Partition (2, 8) is in cluster 0
# Partition (2, 9) is in cluster 0
# Partition (2, 10) is in cluster 0
# Partition (2, 11) is in cluster 0
# Partition (2, 12) is in cluster 0
# Partition (2, 13) is in cluster 0
# Partition (2, 14) is in cluster 0
# Partition (2, 15) is in cluster 0
# Partition (2, 16) is in cluster 0
# Partition (2, 17) is in cluster 0
# Partition (2, 18) is in cluster 0
# Partition (2, 19) is in cluster 0
# Partition (3, 0) is in cluster 0
# Partition (3, 1) is in cluster 0
# Partition (3, 2) is in cluster 0
# Partition (3, 3) is in cluster 0
# Partition (3, 4) is in cluster 0
# Partition (3, 5) is in cluster 0
# Partition (3, 6) is in cluster 0
# Partition (3, 7) is in cluster 0
# Partition (3, 8) is in cluster 0
# Partition (3, 9) is in cluster 0
# Partition (3, 10) is in cluster 0
# Partition (3, 11) is in cluster 0
# Partition (3, 12) is in cluster 0
# Partition (3, 13) is in cluster 0
# Partition (3, 14) is in cluster 0
# Partition (3, 15) is in cluster 0
# Partition (3, 16) is in cluster 0
# Partition (3, 17) is in cluster 0
# Partition (3, 18) is in cluster 0
# Partition (3, 19) is in cluster 0
# Partition (4, 0) is in cluster 2
# Partition (4, 1) is in cluster 1
# Partition (4, 2) is in cluster 1
# Partition (4, 3) is in cluster 0
# Partition (4, 4) is in cluster 0
# Partition (4, 5) is in cluster 0
# Partition (4, 6) is in cluster 0
# Partition (4, 7) is in cluster 0
# Partition (4, 8) is in cluster 0
# Partition (4, 9) is in cluster 0
# Partition (4, 10) is in cluster 0
# Partition (4, 11) is in cluster 0
# Partition (4, 12) is in cluster 0
# Partition (4, 13) is in cluster 0
# Partition (4, 14) is in cluster 0
# Partition (4, 15) is in cluster 0
# Partition (4, 16) is in cluster 0
# Partition (4, 17) is in cluster 0
# Partition (4, 18) is in cluster 0
# Partition (4, 19) is in cluster 2
# Partition (5, 0) is in cluster 1
# Partition (5, 1) is in cluster 2
# Partition (5, 2) is in cluster 2
# Partition (5, 3) is in cluster 2
# Partition (5, 4) is in cluster 0
# Partition (5, 5) is in cluster 0
# Partition (5, 6) is in cluster 0
# Partition (5, 7) is in cluster 0
# Partition (5, 8) is in cluster 0
# Partition (5, 9) is in cluster 0
# Partition (5, 10) is in cluster 0
# Partition (5, 11) is in cluster 2
# Partition (5, 12) is in cluster 0
# Partition (5, 13) is in cluster 0
# Partition (5, 14) is in cluster 0
# Partition (5, 15) is in cluster 0
# Partition (5, 16) is in cluster 0
# Partition (5, 17) is in cluster 0
# Partition (5, 18) is in cluster 0
# Partition (5, 19) is in cluster 2
# Partition (6, 0) is in cluster 0
# Partition (6, 1) is in cluster 0
# Partition (6, 2) is in cluster 0
# Partition (6, 3) is in cluster 0
# Partition (6, 4) is in cluster 0
# Partition (6, 5) is in cluster 0
# Partition (6, 6) is in cluster 0
# Partition (6, 7) is in cluster 2
# Partition (6, 8) is in cluster 2
# Partition (6, 9) is in cluster 0
# Partition (6, 10) is in cluster 1
# Partition (6, 11) is in cluster 2
# Partition (6, 12) is in cluster 0
# Partition (6, 13) is in cluster 0
# Partition (6, 14) is in cluster 0
# Partition (6, 15) is in cluster 0
# Partition (6, 16) is in cluster 0
# Partition (6, 17) is in cluster 0
# Partition (6, 18) is in cluster 0
# Partition (6, 19) is in cluster 0
# Partition (7, 0) is in cluster 0
# Partition (7, 1) is in cluster 0
# Partition (7, 2) is in cluster 0
# Partition (7, 3) is in cluster 2
# Partition (7, 4) is in cluster 2
# Partition (7, 5) is in cluster 0
# Partition (7, 6) is in cluster 2
# Partition (7, 7) is in cluster 0
# Partition (7, 8) is in cluster 1
# Partition (7, 9) is in cluster 1
# Partition (7, 10) is in cluster 1
# Partition (7, 11) is in cluster 0
# Partition (7, 12) is in cluster 0
# Partition (7, 13) is in cluster 0
# Partition (7, 14) is in cluster 0
# Partition (7, 15) is in cluster 0
# Partition (7, 16) is in cluster 0
# Partition (7, 17) is in cluster 0
# Partition (7, 18) is in cluster 0
# Partition (7, 19) is in cluster 0
# Partition (8, 0) is in cluster 0
# Partition (8, 1) is in cluster 0
# Partition (8, 2) is in cluster 0
# Partition (8, 3) is in cluster 2
# Partition (8, 4) is in cluster 1
# Partition (8, 5) is in cluster 2
# Partition (8, 6) is in cluster 1
# Partition (8, 7) is in cluster 1
# Partition (8, 8) is in cluster 1
# Partition (8, 9) is in cluster 1
# Partition (8, 10) is in cluster 1
# Partition (8, 11) is in cluster 0
# Partition (8, 12) is in cluster 0
# Partition (8, 13) is in cluster 0
# Partition (8, 14) is in cluster 0
# Partition (8, 15) is in cluster 0
# Partition (8, 16) is in cluster 0
# Partition (8, 17) is in cluster 0
# Partition (8, 18) is in cluster 0
# Partition (8, 19) is in cluster 0
# Partition (9, 0) is in cluster 0
# Partition (9, 1) is in cluster 0
# Partition (9, 2) is in cluster 0
# Partition (9, 3) is in cluster 0
# Partition (9, 4) is in cluster 0
# Partition (9, 5) is in cluster 0
# Partition (9, 6) is in cluster 2
# Partition (9, 7) is in cluster 2
# Partition (9, 8) is in cluster 1
# Partition (9, 9) is in cluster 2
# Partition (9, 10) is in cluster 2
# Partition (9, 11) is in cluster 0
# Partition (9, 12) is in cluster 0
# Partition (9, 13) is in cluster 0
# Partition (9, 14) is in cluster 0
# Partition (9, 15) is in cluster 0
# Partition (9, 16) is in cluster 0
# Partition (9, 17) is in cluster 0
# Partition (9, 18) is in cluster 0
# Partition (9, 19) is in cluster 0
# Partition (10, 0) is in cluster 2
# Partition (10, 1) is in cluster 2
# Partition (10, 2) is in cluster 0
# Partition (10, 3) is in cluster 0
# Partition (10, 4) is in cluster 0
# Partition (10, 5) is in cluster 0
# Partition (10, 6) is in cluster 0
# Partition (10, 7) is in cluster 0
# Partition (10, 8) is in cluster 0
# Partition (10, 9) is in cluster 0
# Partition (10, 10) is in cluster 0
# Partition (10, 11) is in cluster 0
# Partition (10, 12) is in cluster 2
# Partition (10, 13) is in cluster 0
# Partition (10, 14) is in cluster 0
# Partition (10, 15) is in cluster 0
# Partition (10, 16) is in cluster 0
# Partition (10, 17) is in cluster 0
# Partition (10, 18) is in cluster 0
# Partition (10, 19) is in cluster 0
# Partition (11, 0) is in cluster 0
# Partition (11, 1) is in cluster 0
# Partition (11, 2) is in cluster 0
# Partition (11, 3) is in cluster 0
# Partition (11, 4) is in cluster 0
# Partition (11, 5) is in cluster 0
# Partition (11, 6) is in cluster 0
# Partition (11, 7) is in cluster 0
# Partition (11, 8) is in cluster 0
# Partition (11, 9) is in cluster 0
# Partition (11, 10) is in cluster 0
# Partition (11, 11) is in cluster 0
# Partition (11, 12) is in cluster 0
# Partition (11, 13) is in cluster 0
# Partition (11, 14) is in cluster 0
# Partition (11, 15) is in cluster 0
# Partition (11, 16) is in cluster 0
# Partition (11, 17) is in cluster 0
# Partition (11, 18) is in cluster 0
# Partition (11, 19) is in cluster 0
# Partition (12, 0) is in cluster 0
# Partition (12, 1) is in cluster 0
# Partition (12, 2) is in cluster 0
# Partition (12, 3) is in cluster 0
# Partition (12, 4) is in cluster 0
# Partition (12, 5) is in cluster 2
# Partition (12, 6) is in cluster 0
# Partition (12, 7) is in cluster 0
# Partition (12, 8) is in cluster 0
# Partition (12, 9) is in cluster 0
# Partition (12, 10) is in cluster 0
# Partition (12, 11) is in cluster 0
# Partition (12, 12) is in cluster 0
# Partition (12, 13) is in cluster 0
# Partition (12, 14) is in cluster 0
# Partition (12, 15) is in cluster 0
# Partition (12, 16) is in cluster 0
# Partition (12, 17) is in cluster 0
# Partition (12, 18) is in cluster 0
# Partition (12, 19) is in cluster 2
# Partition (13, 0) is in cluster 0
# Partition (13, 1) is in cluster 0
# Partition (13, 2) is in cluster 0
# Partition (13, 3) is in cluster 0
# Partition (13, 4) is in cluster 0
# Partition (13, 5) is in cluster 0
# Partition (13, 6) is in cluster 0
# Partition (13, 7) is in cluster 0
# Partition (13, 8) is in cluster 0
# Partition (13, 9) is in cluster 0
# Partition (13, 10) is in cluster 0
# Partition (13, 11) is in cluster 0
# Partition (13, 12) is in cluster 0
# Partition (13, 13) is in cluster 0
# Partition (13, 14) is in cluster 0
# Partition (13, 15) is in cluster 0
# Partition (13, 16) is in cluster 0
# Partition (13, 17) is in cluster 0
# Partition (13, 18) is in cluster 0
# Partition (13, 19) is in cluster 0
# Partition (14, 0) is in cluster 0
# Partition (14, 1) is in cluster 0
# Partition (14, 2) is in cluster 0
# Partition (14, 3) is in cluster 0
# Partition (14, 4) is in cluster 0
# Partition (14, 5) is in cluster 0
# Partition (14, 6) is in cluster 0
# Partition (14, 7) is in cluster 0
# Partition (14, 8) is in cluster 0
# Partition (14, 9) is in cluster 0
# Partition (14, 10) is in cluster 0
# Partition (14, 11) is in cluster 0
# Partition (14, 12) is in cluster 0
# Partition (14, 13) is in cluster 0
# Partition (14, 14) is in cluster 0
# Partition (14, 15) is in cluster 0
# Partition (14, 16) is in cluster 0
# Partition (14, 17) is in cluster 0
# Partition (14, 18) is in cluster 0
# Partition (14, 19) is in cluster 0
# Partition (15, 0) is in cluster 0
# Partition (15, 1) is in cluster 0
# Partition (15, 2) is in cluster 0
# Partition (15, 3) is in cluster 0
# Partition (15, 4) is in cluster 0
# Partition (15, 5) is in cluster 0
# Partition (15, 6) is in cluster 0
# Partition (15, 7) is in cluster 0
# Partition (15, 8) is in cluster 0
# Partition (15, 9) is in cluster 0
# Partition (15, 10) is in cluster 0
# Partition (15, 11) is in cluster 0
# Partition (15, 12) is in cluster 0
# Partition (15, 13) is in cluster 0
# Partition (15, 14) is in cluster 0
# Partition (15, 15) is in cluster 0
# Partition (15, 16) is in cluster 0
# Partition (15, 17) is in cluster 0
# Partition (15, 18) is in cluster 0
# Partition (15, 19) is in cluster 0
# Partition (16, 0) is in cluster 0
# Partition (16, 1) is in cluster 0
# Partition (16, 2) is in cluster 0
# Partition (16, 3) is in cluster 0
# Partition (16, 4) is in cluster 0
# Partition (16, 5) is in cluster 0
# Partition (16, 6) is in cluster 0
# Partition (16, 7) is in cluster 0
# Partition (16, 8) is in cluster 0
# Partition (16, 9) is in cluster 0
# Partition (16, 10) is in cluster 0
# Partition (16, 11) is in cluster 0
# Partition (16, 12) is in cluster 0
# Partition (16, 13) is in cluster 0
# Partition (16, 14) is in cluster 0
# Partition (16, 15) is in cluster 0
# Partition (16, 16) is in cluster 0
# Partition (16, 17) is in cluster 0
# Partition (16, 18) is in cluster 0
# Partition (16, 19) is in cluster 0

# %% [markdown]
# <h3> &#128583; Step 11 - Map cluster labels to attractiveness levels</h3>
#
# You are not granted that lowest values are in cluster 0, medium in cluster 1, and highest in cluster 2.
#
# Check for _centers_attractiveness_clustering_ and manually map cluster labels to attractiveness levels if necessary.

# %%
centers_attractiveness_clustering
# Out:
# array([[112.47],
#        [983.  ],
#        [478.5 ]])

# %%
# In my case, centers_attractiveness_clustering was
# array([[112.47],
#        [983.  ],
#        [478.5 ]])
# So, my mapping is:
for y in range(partitions_h):
    for x in range(partitions_w):
        if partitions_tbl[y][x].attractiveness_cat == 0:
            attractiveness = 0
        if partitions_tbl[y][x].attractiveness_cat == 1:
            attractiveness = 2
        if partitions_tbl[y][x].attractiveness_cat == 2:
            attractiveness = 1
        partitions_tbl[y][x].attractiveness_cat = attractiveness

# %% [markdown]
# <h3> &#128582; Step 12 - Map of Attractiveness</h3>
#
# Run the cell here below to display the map of the attractiveness in the territory of your interest.
#
# __Remark__: the map displays _relative_ quantifications of attractiveness, i.e. you find marked in red those areas that are less attractive than others _within the boundaries of the considered territory_.

# %%
map_attractiveness = folium.Map(location=[(lat_min+lat_max)/2, (lon_min+lon_max)/2], zoom_start=13)
rainbow = [colors.rgb2hex(colors.BASE_COLORS["r"]), colors.rgb2hex(colors.BASE_COLORS["y"]), colors.rgb2hex(colors.BASE_COLORS["g"])]
markers_colors = []
for y in range(partitions_h):
    for x in range(partitions_w):
        label = folium.Popup("Attractiveness here is "+str(partitions_tbl[y][x].attractiveness_cat)+" in a 0 - 2 scale", parse_html=True)
        lat = (partitions_tbl[y][x].lat_min+partitions_tbl[y][x].lat_max)/2
        lon = (partitions_tbl[y][x].lon_min+partitions_tbl[y][x].lon_max)/2        
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[partitions_tbl[y][x].attractiveness_cat],
            fill=True,
            fill_color=rainbow[partitions_tbl[y][x].attractiveness_cat],
            fill_opacity=0.7).add_to(map_attractiveness)       
map_attractiveness
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3> &#128582; Step 13 - Gap computation</h3>
#
# Run the cell here below to compute the gap among attractiveness and level of mobility services and infrastructures, for each partition of the territory of interest.

# %%
for y in range(partitions_h):
    for x in range(partitions_w):
        partitions_tbl[y][x].gap = partitions_tbl[y][x].mobility_cat - partitions_tbl[y][x].attractiveness_cat + 2

# %% [markdown]
# <h3> &#128582; Step 14 - Gap visualization</h3>
#
# Run the cell here below to display a map where areas that would need investments in mobility services and infrastructures are highlighted in red, areas that are very well served are marked in green, intermediate areas are marked with intermediate colors.

# %%
map_gap = folium.Map(location=[(lat_min+lat_max)/2, (lon_min+lon_max)/2], zoom_start=13)
rainbow = [colors.rgb2hex(colors.BASE_COLORS["r"]), colors.rgb2hex(colors.TABLEAU_COLORS["tab:orange"]), colors.rgb2hex(colors.BASE_COLORS["y"]), colors.rgb2hex(colors.TABLEAU_COLORS["tab:green"]), colors.rgb2hex(colors.BASE_COLORS["g"])]
markers_colors = []
for y in range(partitions_h):
    for x in range(partitions_w):
        label = folium.Popup("Gap here is "+str(partitions_tbl[y][x].gap)+" in a 0 - 4 scale", parse_html=True)
        lat = (partitions_tbl[y][x].lat_min+partitions_tbl[y][x].lat_max)/2
        lon = (partitions_tbl[y][x].lon_min+partitions_tbl[y][x].lon_max)/2        
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[partitions_tbl[y][x].gap],
            fill=True,
            fill_color=rainbow[partitions_tbl[y][x].gap],
            fill_opacity=0.7).add_to(map_gap)       
map_gap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
